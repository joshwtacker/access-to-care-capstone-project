# %%
#!pip install uszipcode
#!pip install 'sqlalchemy_mate < 2.0.0.1'
#!pip install us

# %%
import pandas as pd
from uszipcode import SearchEngine
import us
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
cdc_24 = pd.read_csv('../data/cleaned/cdc_cleaned_2024.csv')
cdc_24
# Out:
#                      county     fips    deaths  Population
# 0        Autauga County, AL   1001.0      50.0      408275
# 1        Baldwin County, AL   1003.0     427.0     1671387
# 2        Barbour County, AL   1005.0      33.0      172769
# 3           Bibb County, AL   1007.0      49.0      155538
# 4         Blount County, AL   1009.0     106.0      412077
# ...                     ...      ...       ...         ...
# 2478  Sweetwater County, WY  56037.0      87.0      293548
# 2479       Teton County, WY  56039.0      12.0      163408
# 2480       Uinta County, WY  56041.0      38.0      143453
# 2481    Washakie County, WY  56043.0      11.0       54246
# 2482                    NaN    00nan  656997.0  2314179815
#
# [2483 rows x 4 columns]

# %%
cdc_24['deaths'].min()
# Out:
# 10.0

# %%
facilities = pd.read_csv('../data/cleaned/samhsa_facilities_zip.csv')
facilities
# Out:
#      state    zip  facility_count
# 0       AK  99501               2
# 1       AK  99503               6
# 2       AK  99507               1
# 3       AK  99508              10
# 4       AK  99518               2
# ...    ...    ...             ...
# 5344    WY  82941               1
# 5345    WY  83001               1
# 5346    WY  83101               1
# 5347    WY  83110               1
# 5348    WY  83127               1
#
# [5349 rows x 3 columns]

# %%
census_24 = pd.read_csv('../data/cleaned/census_acs_2024.csv')
census_24
# Out:
#                            county_name  median_income  population  state  \
# 0              Autauga County, Alabama          72481       59947      1
# 1              Baldwin County, Alabama          78775      246989      1
# 2              Barbour County, Alabama          46042       24643      1
# 3                 Bibb County, Alabama          52541       22130      1
# 4               Blount County, Alabama          64190       59518      1
# ...                                ...            ...         ...    ...
# 3217  Vega Baja Municipio, Puerto Rico          24244       53892     72
# 3218    Vieques Municipio, Puerto Rico          19803        8078     72
# 3219   Villalba Municipio, Puerto Rico          26286       21556     72
# 3220    Yabucoa Municipio, Puerto Rico          22944       29400     72
# 3221      Yauco Municipio, Puerto Rico          24255       32993     72
#
#       county  poverty_rate  unemployment_rate   fips
# 0          1          11.3                2.4   1001
# 1          3          10.1                3.0   1003
# 2          5          21.4                7.8   1005
# 3          7          22.5               12.1   1007
# 4          9          12.9                5.0   1009
# ...      ...           ...                ...    ...
# 3217     145          41.1               11.0  72145
# 3218     147          59.1                6.1  72147
# 3219     149          38.9               11.4  72149
# 3220     151          47.7                8.7  72151
# 3221     153          41.9               11.9  72153
#
# [3222 rows x 8 columns]

# %% [markdown]
# ## To begin this notebook I need to make sure that my county columns are able to be merged on for all of my datasets.

# %%
search = SearchEngine()

facilities["county"] = (
    facilities["zip"]
    .apply(
        lambda z:
        search.by_zipcode(z).county
        if search.by_zipcode(z)
        else None
    )
)

facilities.head()
# Out:
#   state    zip  facility_count                  county
# 0    AK  99501               2  Anchorage Municipality
# 1    AK  99503               6  Anchorage Municipality
# 2    AK  99507               1  Anchorage Municipality
# 3    AK  99508              10  Anchorage Municipality
# 4    AK  99518               2  Anchorage Municipality

# %%
facilities.sample(5)
# Out:
#      state    zip  facility_count            county
# 1440    IA  50138               2     Marion County
# 4085    OR  97702               3  Deschutes County
# 1881    IN  46923               1    Carroll County
# 4374    TN  37745               1     Greene County
# 5096    WI  53005               2   Waukesha County

# %%
facilities['county_state'] = facilities['county'] + ', ' + facilities['state']
facilities.head()
# Out:
#   state    zip  facility_count                  county  \
# 0    AK  99501               2  Anchorage Municipality
# 1    AK  99503               6  Anchorage Municipality
# 2    AK  99507               1  Anchorage Municipality
# 3    AK  99508              10  Anchorage Municipality
# 4    AK  99518               2  Anchorage Municipality
#
#                  county_state
# 0  Anchorage Municipality, AK
# 1  Anchorage Municipality, AK
# 2  Anchorage Municipality, AK
# 3  Anchorage Municipality, AK
# 4  Anchorage Municipality, AK

# %%
facilities = facilities.groupby('county_state')['facility_count'].sum().reset_index()
facilities
# Out:
#                        county_state  facility_count
# 0                              , GU               1
# 1                              , MP               1
# 2                 Acadia Parish, LA               1
# 3               Accomack County, VA               2
# 4                    Ada County, ID              36
# ...                             ...             ...
# 2082                Yuba County, CA               4
# 2083  Yukon-Koyukuk Census Area, AK               1
# 2084                Yuma County, AZ              15
# 2085                Yuma County, CO               1
# 2086              Zavala County, TX               1
#
# [2087 rows x 2 columns]

# %%
cdc_24["fips"] = (
    cdc_24["fips"]
    .astype(str)
    .str.zfill(5)
)

census_24["fips"] = (
    census_24["fips"]
    .astype(str)
    .str.zfill(5)
)

# %%
#rename state and county column to mergre on
cdc_24 = cdc_24.rename(columns= {'county': 'county_state'})
cdc_24.head(2)
# Out:
#          county_state    fips  deaths Population
# 0  Autauga County, AL  1001.0    50.0     408275
# 1  Baldwin County, AL  1003.0   427.0    1671387

# %%
census_24 = census_24.rename(columns= {'county_name': 'county_state'})
census_24.head(2)
# Out:
#               county_state  median_income  population  state  county  \
# 0  Autauga County, Alabama          72481       59947      1       1
# 1  Baldwin County, Alabama          78775      246989      1       3
#
#    poverty_rate  unemployment_rate   fips
# 0          11.3                2.4  01001
# 1          10.1                3.0  01003

# %%
def safe_state_lookup(state_name):
    """Safely lookup state abbreviation, return original name if not found"""
    try:
        state = us.states.lookup(state_name.strip())  # Remove extra whitespace
        return state.abbr if state else state_name  # Return abbr if found, else original name
    except:
        return state_name  # Return original name if any error occurs

census_24['county_state'] = (
    census_24['county_state']
    .str.split(', ')
    .apply(lambda x: f"{x[0]}, {safe_state_lookup(x[1])}")
)

census_24.head(2)
# Out:
#          county_state  median_income  population  state  county  poverty_rate  \
# 0  Autauga County, AL          72481       59947      1       1          11.3
# 1  Baldwin County, AL          78775      246989      1       3          10.1
#
#    unemployment_rate   fips
# 0                2.4  01001
# 1                3.0  01003

# %%
census_24['county_state'].value_counts()
# Out:
# county_state
# Autauga County, AL     1
# Custer County, OK      1
# Carter County, OK      1
# Cherokee County, OK    1
# Choctaw County, OK     1
#                       ..
# Meade County, KY       1
# Menifee County, KY     1
# Mercer County, KY      1
# Metcalfe County, KY    1
# Yauco Municipio, PR    1
# Name: count, Length: 3222, dtype: int64

# %%
facilities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   county_state    2087 non-null   object
#  1   facility_count  2087 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 32.7+ KB

# %% [markdown]
# ## Merging

# %%
facilities.head(2)
# Out:
#   county_state  facility_count
# 0         , GU               1
# 1         , MP               1

# %%
master_raw = cdc_24.merge(census_24, on='county_state') \
               .merge(facilities, on='county_state', how= 'right')
master_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   county_state       2087 non-null   object
#  1   fips_x             1887 non-null   object
#  2   deaths             1887 non-null   float64
#  3   Population         1887 non-null   object
#  4   median_income      1887 non-null   float64
#  5   population         1887 non-null   float64
#  6   state              1887 non-null   float64
#  7   county             1887 non-null   float64
#  8   poverty_rate       1887 non-null   float64
#  9   unemployment_rate  1887 non-null   float64
#  10  fips_y             1887 non-null   object
#  11  facility_count     2087 non-null   int64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 195.8+ KB

# %%
master_raw.shape
# Out:
# (2087, 12)

# %%
master_raw.head(2)
# Out:
#   county_state fips_x  deaths Population  median_income  population  state  \
# 0         , GU    NaN     NaN        NaN            NaN         NaN    NaN
# 1         , MP    NaN     NaN        NaN            NaN         NaN    NaN
#
#    county  poverty_rate  unemployment_rate fips_y  facility_count
# 0     NaN           NaN                NaN    NaN               1
# 1     NaN           NaN                NaN    NaN               1

# %%
master_raw['county_state']
# Out:
# 0                                , GU
# 1                                , MP
# 2                   Acadia Parish, LA
# 3                 Accomack County, VA
# 4                      Ada County, ID
#                     ...
# 2082                  Yuba County, CA
# 2083    Yukon-Koyukuk Census Area, AK
# 2084                  Yuma County, AZ
# 2085                  Yuma County, CO
# 2086                Zavala County, TX
# Name: county_state, Length: 2087, dtype: object

# %% [markdown]
# ### Now that I have my raw master data frame I can clean it up

# %%
master_raw = master_raw.drop(columns=['state', 'county', 'fips_y'])

# %%
master_raw.head(2)
# Out:
#   county_state fips_x  deaths Population  median_income  population  \
# 0         , GU    NaN     NaN        NaN            NaN         NaN
# 1         , MP    NaN     NaN        NaN            NaN         NaN
#
#    poverty_rate  unemployment_rate  facility_count
# 0           NaN                NaN               1
# 1           NaN                NaN               1

# %%
master = master_raw.rename(columns={
    'fips_x': 'fips'
})

# %%
#last clean up 
#last clean up 
master['fips'] = (
    master['fips']
    .fillna(0)
    .astype(float)  # First convert to float to handle any string decimals
    .astype(int)    # Then convert to int (this removes decimal places)
    .astype(str)    # Convert to string for zfill formatting
    .str.zfill(5)   # Pad with leading zeros to make 5 digits
)

# %%
master.head(2)
# Out:
#   county_state   fips  deaths Population  median_income  population  \
# 0         , GU  00000     NaN        NaN            NaN         NaN
# 1         , MP  00000     NaN        NaN            NaN         NaN
#
#    poverty_rate  unemployment_rate  facility_count
# 0           NaN                NaN               1
# 1           NaN                NaN               1

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   county_state       2087 non-null   object
#  1   fips               2087 non-null   object
#  2   deaths             1887 non-null   float64
#  3   Population         1887 non-null   object
#  4   median_income      1887 non-null   float64
#  5   population         1887 non-null   float64
#  6   poverty_rate       1887 non-null   float64
#  7   unemployment_rate  1887 non-null   float64
#  8   facility_count     2087 non-null   int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 146.9+ KB

# %%
master.shape
# Out:
# (2087, 9)

# %% [markdown]
# ## Now that I have my Master Data Frame, will add come variables that I plan to work with.

# %%
master.columns[master.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
#analysis variable
master["overdose_rate"] = (
    master["deaths"]
    /
    master["population"]
) * 100000

# %%
master["facility_rate"] = (
    master["facility_count"]
    /
    master["population"]
) * 100000

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   county_state       2087 non-null   object
#  1   fips               2087 non-null   object
#  2   deaths             1887 non-null   float64
#  3   Population         1887 non-null   object
#  4   median_income      1887 non-null   float64
#  5   population         1887 non-null   float64
#  6   poverty_rate       1887 non-null   float64
#  7   unemployment_rate  1887 non-null   float64
#  8   facility_count     2087 non-null   int64
#  9   overdose_rate      1887 non-null   float64
#  10  facility_rate      1887 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 179.5+ KB

# %% [markdown]
# Now lets save it as a csv

# %%
master.to_csv('../data/master_df.csv', index=False)
